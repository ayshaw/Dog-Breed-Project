# %%
from bs4 import BeautifulSoup
import requests
import re
import matplotlib.pylab as plt
import matplotlib.image as mping
import os
import pandas as pd
import numpy as np
import collections
import seaborn as sns
import multiprocessing
import cv2
from keras.utils import to_categorical
print(multiprocessing.cpu_count())
# Imports keras
import keras
from keras.layers import Conv2D, MaxPooling2D, Dense, Input, Flatten, Dropout, UpSampling2D, GlobalAveragePooling2D
from keras.models import Model, Sequential
from keras.optimizers import Adam, SGD
from keras.applications.vgg16 import VGG16
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input, decode_predictions
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image
# %matplotlib inline

from keras.applications import resnet50
# Out:
# Using TensorFlow backend.
# 32

# %%
def resize2(im,desired_size=250):
    old_size = im.shape[:2] 
    ratio = float(desired_size)/min(old_size)
    new_size = tuple([int(x*ratio) for x in old_size])
    im2 = cv2.resize(im, (new_size[1], new_size[0]))
    if im2.shape[0]>250:
        mid=int(im2.shape[0]/2)
        lt=mid-125
        rt=mid+125
        im3=im2[lt:rt,:,:]
    else:
        mid=int(im2.shape[1]/2)
        lt=mid-125
        rt=mid+125
        im3=im2[:,lt:rt,:]
    im4=cv2.resize(im3,(250,250))/255
    return im4

# %%
def resize3(im,desired_size=250):
    old_size = im.shape[:2] 
    idx = np.argmax(old_size)
    new_size = np.zeros(2)
    new_size[0] = int((desired_size*old_size[0])/old_size[idx])
    new_size[1] = int((desired_size*old_size[1])//old_size[idx])
    new_size[idx] = int(desired_size)
    im2 = cv2.resize(im, (int(new_size[1]), int(new_size[0])))
    if im2.shape[0]<desired_size:
        im3 = np.zeros((desired_size,desired_size,im2.shape[-1]))
        im3[:im2.shape[0],:,:]=im2
    else:
        im3 = np.zeros((desired_size,desired_size,im2.shape[-1]))
        im3[:,:im2.shape[1],:]=im2[:,:,:]
    return im3[:,:,:3].astype('int')

# %%
count = 0
img_all = []
width_tot=[]
height_tot=[]
for h,_,fs in os.walk('Images/'):
    for f in fs:
        if f.endswith('.jpg'):
            img = mping.imread(h+'/'+f)
            img_all.append(img)
    count += 1
    print(count)
    if count>5:
        break
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
ratio_tot=[]
for im in img_all:
    width, height, depth = im.shape
    ratio = height/width
    ratio_tot.append(ratio)
    
plt.figure(figsize=(12,8))
plt.hist(ratio_tot, alpha =0.5)
#plt.hist(height_tot, alpha =0.5, label= "height")
plt.xlabel("height/width", size =15)
plt.ylabel("Frequency", size =15)
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.title("Distribution of Image Size Ratio", fontsize =20)
#plt.legend(prop={'size':15})
plt.savefig('distribution_size.png')

# %%
# Scrape information from AKC website
page = requests.get('https://www.akc.org/dog-breeds/sporting/page/3')
soup = BeautifulSoup(page.content,'html.parser')
name_links = soup.select_one('select."custom-select__select"').select('option')[1:]
group_map = {}
for p in name_links:
    link = p.get('value')
    l_soup = BeautifulSoup(requests.get(link).content,'html.parser')
    group_map[p.text.lower()]=l_soup.select_one('li > span > a').text

# %%
# Classify and correct every groups
cls = !ls Images/
cls = [c.split('-')[1].replace('_',' ') for c in cls]
groups1 = {}
groups2 = {}
first_word = [re.split(' |-',c)[0] for c in group_map.keys()]
count1 = 0
count2 = 0
for c in cls:
    if c.lower() in group_map.keys():
        groups1[c.lower()] = group_map[c.lower()]
    elif c.split(' ')[0].lower() in first_word:
        idx = first_word.index(c.split(' ')[0].lower())
        groups2[c.lower()] = list(group_map.values())[idx]
        count1 += 1
    else:
        print(c)
        count2 += 1
groups3 = {}
groups3['pekinese'] = 'Toy Group'
groups3['leonberg'] = 'Working Group'
groups3['african hunting dog'] = 'NAN' # Not sure about this one, suspect it is Basenji Dog
groups3['blenheim spaniel'] = 'Toy Group' # Also known as Cavalier King Charles Spaniel
groups3['walker hound'] = 'Hound Group' # Full name is Treeing Walker Coonhound
groups3['scotch terrier'] = 'Terrier Group' # aka Scottish Terrier
groups3['groenendael'] = 'Herding Group' # A branch of Belgian Sheepdog
groups3['malinois'] = 'Herding Group' # Formally as Belgian Malinois
groups3['kelpie'] = 'Foundation Stock Service' # Formally as Australian Kelpie
groups3['eskimo dog'] = 'Non-Sporting Group' # Formally as American Eskimo Dog
groups3['malamute'] = 'Working Group' # Formally as Alaskan Malamute
groups3['brabancon griffon'] = 'Hybrid' # Brabancon and Brussels Griffon hybrid
groups3['mexican hairless'] = 'Non-Sporting Group' # Formally as Xoloitzcuintli
groups3['dingo'] = 'NAN' # Originally considered as wolf, now believed to be a independent branch
groups3['dhole'] = 'NAN' # ALso close to wolf, not clear which superclass it belongs to
# groups2['Boston bull'] is the only one in American Kennel website starting with Boston, assume it's the one
# groups2['English springer'] is labeled correctly for the wrong reason
groups2['german shepherd'] = 'Herding Group'
groups2['german short'] = 'Sporting Group'
groups2['basset'] = 'Hound Group'
groups2['bull mastiff'] = 'Working Group'
groups2['miniature poodle'] = 'Non-Sporting Group'
groups2['standard poodle'] = 'Non-Sporting Group'
groups2['toy poodle'] = 'Non-Sporting Group' # Assuming that toy poodle is a kind of poodle anyways
# groups2['wire'] is wire-haired fox terrier, assume it's the same as wire fox terrier, though there is a group of wirehaired
groups = {**groups1,**groups2,**groups3}
# Out:
# Pekinese
# Blenheim spaniel
# Walker hound
# Scotch terrier
# groenendael
# malinois
# kelpie
# Eskimo dog
# malamute
# Leonberg
# Brabancon griffon
# Mexican hairless
# dingo
# dhole
# African hunting dog

# %%
# Generate train and test set, SET the first two lines
no_train = 3
no_test = 0
data_train = []
data_test = []
cat = 0
for h,_,fs in os.walk('/n/home03/xwei/Desktop/Images/'):
    count = 0
    for f in fs:
        if f.endswith('.jpg'):
            img = mping.imread(h+'/'+f)
            count += 1
            meta = []
            with open((h+'/'+f).replace('Images','Annotation').replace('.jpg',''),'r') as fp:
                print((h))
                soup = BeautifulSoup(fp.read(),'html.parser')
                xmin = int(soup.select_one('xmin').text)
                xmax = int(soup.select_one('xmax').text)
                ymin = int(soup.select_one('ymin').text)
                ymax = int(soup.select_one('ymax').text)
                img = img[ymin:ymax,xmin:xmax,:]
            meta.append(resize3(img,64))
            meta.append(h.split('/')[-1].split('-')[1].replace('_',' ').lower())
            meta.append(groups[h.split('/')[-1].split('-')[1].replace('_',' ').lower()])
            if count <= no_train:
                data_train.append(meta)
            elif count <= no_train + no_test:
                data_test.append(meta)
            else:
                break
    cat += 1
#     if cat == 3:
#         break
# Out:
# /n/home03/xwei/Desktop/Images/n02107574-Greater_Swiss_Mountain_dog
# /n/home03/xwei/Desktop/Images/n02107574-Greater_Swiss_Mountain_dog
# /n/home03/xwei/Desktop/Images/n02107574-Greater_Swiss_Mountain_dog
# /n/home03/xwei/Desktop/Images/n02107574-Greater_Swiss_Mountain_dog
# /n/home03/xwei/Desktop/Images/n02100236-German_short-haired_pointer
# /n/home03/xwei/Desktop/Images/n02100236-German_short-haired_pointer
# /n/home03/xwei/Desktop/Images/n02100236-German_short-haired_pointer
# /n/home03/xwei/Desktop/Images/n02100236-German_short-haired_pointer
# /n/home03/xwei/Desktop/Images/n02088632-bluetick
# /n/home03/xwei/Desktop/Images/n02088632-bluetick
# /n/home03/xwei/Desktop/Images/n02088632-bluetick
# /n/home03/xwei/Desktop/Images/n02088632-bluetick
# /n/home03/xwei/Desktop/Images/n02106550-Rottweiler
# /n/home03/xwei/Desktop/Images/n02106550-Rottweiler
# /n/home03/xwei/Desktop/Images/n02106550-Rottweiler
# /n/home03/xwei/Desktop/Images/n02106550-Rottweiler
# /n/home03/xwei/Desktop/Images/n02105641-Old_English_sheepdog
# /n/home03/xwei/Desktop/Images/n02105641-Old_English_sheepdog
# /n/home03/xwei/Desktop/Images/n02105641-Old_English_sheepdog
# /n/home03/xwei/Desktop/Images/n02105641-Old_English_sheepdog
# /n/home03/xwei/Desktop/Images/n02094433-Yorkshire_terrier
# /n/home03/xwei/Desktop/Images/n02094433-Yorkshire_terrier
# /n/home03/xwei/Desktop/Images/n02094433-Yorkshire_terrier
# /n/home03/xwei/Desktop/Images/n02094433-Yorkshire_terrier
# /n/home03/xwei/Desktop/Images/n02110063-malamute
# /n/home03/xwei/Desktop/Images/n02110063-malamute
# /n/home03/xwei/Desktop/Images/n02110063-malamute
# /n/home03/xwei/Desktop/Images/n02110063-malamute
# /n/home03/xwei/Desktop/Images/n02108551-Tibetan_mastiff
# /n/home03/xwei/Desktop/Images/n02108551-Tibetan_mastiff
# /n/home03/xwei/Desktop/Images/n02108551-Tibetan_mastiff
# /n/home03/xwei/Desktop/Images/n02108551-Tibetan_mastiff
# /n/home03/xwei/Desktop/Images/n02106166-Border_collie
# /n/home03/xwei/Desktop/Images/n02106166-Border_collie
# /n/home03/xwei/Desktop/Images/n02106166-Border_collie
# /n/home03/xwei/Desktop/Images/n02106166-Border_collie
# /n/home03/xwei/Desktop/Images/n02094258-Norwich_terrier
# /n/home03/xwei/Desktop/Images/n02094258-Norwich_terrier
# /n/home03/xwei/Desktop/Images/n02094258-Norwich_terrier
# /n/home03/xwei/Desktop/Images/n02094258-Norwich_terrier
# /n/home03/xwei/Desktop/Images/n02097474-Tibetan_terrier
# /n/home03/xwei/Desktop/Images/n02097474-Tibetan_terrier
# /n/home03/xwei/Desktop/Images/n02097474-Tibetan_terrier
# /n/home03/xwei/Desktop/Images/n02097474-Tibetan_terrier
# /n/home03/xwei/Desktop/Images/n02099601-golden_retriever
# /n/home03/xwei/Desktop/Images/n02099601-golden_retriever
# /n/home03/xwei/Desktop/Images/n02099601-golden_retriever
# /n/home03/xwei/Desktop/Images/n02099601-golden_retriever
# /n/home03/xwei/Desktop/Images/n02107908-Appenzeller
# /n/home03/xwei/Desktop/Images/n02107908-Appenzeller
# /n/home03/xwei/Desktop/Images/n02107908-Appenzeller
# /n/home03/xwei/Desktop/Images/n02107908-Appenzeller
# /n/home03/xwei/Desktop/Images/n02100877-Irish_setter
# /n/home03/xwei/Desktop/Images/n02100877-Irish_setter
# /n/home03/xwei/Desktop/Images/n02100877-Irish_setter
# /n/home03/xwei/Desktop/Images/n02100877-Irish_setter
# /n/home03/xwei/Desktop/Images/n02086079-Pekinese
# /n/home03/xwei/Desktop/Images/n02086079-Pekinese
# /n/home03/xwei/Desktop/Images/n02086079-Pekinese
# /n/home03/xwei/Desktop/Images/n02086079-Pekinese
# /n/home03/xwei/Desktop/Images/n02085782-Japanese_spaniel
# /n/home03/xwei/Desktop/Images/n02085782-Japanese_spaniel
# /n/home03/xwei/Desktop/Images/n02085782-Japanese_spaniel
# /n/home03/xwei/Desktop/Images/n02085782-Japanese_spaniel
# /n/home03/xwei/Desktop/Images/n02096437-Dandie_Dinmont
# /n/home03/xwei/Desktop/Images/n02096437-Dandie_Dinmont
# /n/home03/xwei/Desktop/Images/n02096437-Dandie_Dinmont
# /n/home03/xwei/Desktop/Images/n02096437-Dandie_Dinmont
# /n/home03/xwei/Desktop/Images/n02112350-keeshond
# /n/home03/xwei/Desktop/Images/n02112350-keeshond
# /n/home03/xwei/Desktop/Images/n02112350-keeshond
# /n/home03/xwei/Desktop/Images/n02112350-keeshond
# /n/home03/xwei/Desktop/Images/n02107142-Doberman
# /n/home03/xwei/Desktop/Images/n02107142-Doberman
# /n/home03/xwei/Desktop/Images/n02107142-Doberman
# /n/home03/xwei/Desktop/Images/n02107142-Doberman
# /n/home03/xwei/Desktop/Images/n02094114-Norfolk_terrier
# /n/home03/xwei/Desktop/Images/n02094114-Norfolk_terrier
# /n/home03/xwei/Desktop/Images/n02094114-Norfolk_terrier
# /n/home03/xwei/Desktop/Images/n02094114-Norfolk_terrier
# /n/home03/xwei/Desktop/Images/n02090622-borzoi
# /n/home03/xwei/Desktop/Images/n02090622-borzoi
# /n/home03/xwei/Desktop/Images/n02090622-borzoi
# /n/home03/xwei/Desktop/Images/n02090622-borzoi
# /n/home03/xwei/Desktop/Images/n02102973-Irish_water_spaniel
# /n/home03/xwei/Desktop/Images/n02102973-Irish_water_spaniel
# /n/home03/xwei/Desktop/Images/n02102973-Irish_water_spaniel
# /n/home03/xwei/Desktop/Images/n02102973-Irish_water_spaniel
# /n/home03/xwei/Desktop/Images/n02106662-German_shepherd
# /n/home03/xwei/Desktop/Images/n02106662-German_shepherd
# /n/home03/xwei/Desktop/Images/n02106662-German_shepherd
# /n/home03/xwei/Desktop/Images/n02106662-German_shepherd
# /n/home03/xwei/Desktop/Images/n02105162-malinois
# /n/home03/xwei/Desktop/Images/n02105162-malinois
# /n/home03/xwei/Desktop/Images/n02105162-malinois
# /n/home03/xwei/Desktop/Images/n02105162-malinois
# /n/home03/xwei/Desktop/Images/n02099712-Labrador_retriever
# /n/home03/xwei/Desktop/Images/n02099712-Labrador_retriever
# /n/home03/xwei/Desktop/Images/n02099712-Labrador_retriever
# /n/home03/xwei/Desktop/Images/n02099712-Labrador_retriever
# /n/home03/xwei/Desktop/Images/n02091134-whippet
# /n/home03/xwei/Desktop/Images/n02091134-whippet
# /n/home03/xwei/Desktop/Images/n02091134-whippet
# /n/home03/xwei/Desktop/Images/n02091134-whippet
# /n/home03/xwei/Desktop/Images/n02097130-giant_schnauzer
# /n/home03/xwei/Desktop/Images/n02097130-giant_schnauzer
# /n/home03/xwei/Desktop/Images/n02097130-giant_schnauzer
# /n/home03/xwei/Desktop/Images/n02097130-giant_schnauzer
# /n/home03/xwei/Desktop/Images/n02102318-cocker_spaniel
# /n/home03/xwei/Desktop/Images/n02102318-cocker_spaniel
# /n/home03/xwei/Desktop/Images/n02102318-cocker_spaniel
# /n/home03/xwei/Desktop/Images/n02102318-cocker_spaniel
# /n/home03/xwei/Desktop/Images/n02099429-curly-coated_retriever
# /n/home03/xwei/Desktop/Images/n02099429-curly-coated_retriever
# /n/home03/xwei/Desktop/Images/n02099429-curly-coated_retriever
# /n/home03/xwei/Desktop/Images/n02099429-curly-coated_retriever
# /n/home03/xwei/Desktop/Images/n02109525-Saint_Bernard
# /n/home03/xwei/Desktop/Images/n02109525-Saint_Bernard
# /n/home03/xwei/Desktop/Images/n02109525-Saint_Bernard
# /n/home03/xwei/Desktop/Images/n02109525-Saint_Bernard
# /n/home03/xwei/Desktop/Images/n02111500-Great_Pyrenees
# /n/home03/xwei/Desktop/Images/n02111500-Great_Pyrenees
# /n/home03/xwei/Desktop/Images/n02111500-Great_Pyrenees
# /n/home03/xwei/Desktop/Images/n02111500-Great_Pyrenees
# /n/home03/xwei/Desktop/Images/n02109961-Eskimo_dog
# /n/home03/xwei/Desktop/Images/n02109961-Eskimo_dog
# /n/home03/xwei/Desktop/Images/n02109961-Eskimo_dog
# /n/home03/xwei/Desktop/Images/n02109961-Eskimo_dog
# /n/home03/xwei/Desktop/Images/n02086240-Shih-Tzu
# /n/home03/xwei/Desktop/Images/n02086240-Shih-Tzu
# /n/home03/xwei/Desktop/Images/n02086240-Shih-Tzu
# /n/home03/xwei/Desktop/Images/n02086240-Shih-Tzu
# /n/home03/xwei/Desktop/Images/n02090379-redbone
# /n/home03/xwei/Desktop/Images/n02090379-redbone
# /n/home03/xwei/Desktop/Images/n02090379-redbone
# /n/home03/xwei/Desktop/Images/n02090379-redbone
# /n/home03/xwei/Desktop/Images/n02089078-black-and-tan_coonhound
# /n/home03/xwei/Desktop/Images/n02089078-black-and-tan_coonhound
# /n/home03/xwei/Desktop/Images/n02089078-black-and-tan_coonhound
# /n/home03/xwei/Desktop/Images/n02089078-black-and-tan_coonhound
# /n/home03/xwei/Desktop/Images/n02088466-bloodhound
# /n/home03/xwei/Desktop/Images/n02088466-bloodhound
# /n/home03/xwei/Desktop/Images/n02088466-bloodhound
# /n/home03/xwei/Desktop/Images/n02088466-bloodhound
# /n/home03/xwei/Desktop/Images/n02096177-cairn
# /n/home03/xwei/Desktop/Images/n02096177-cairn
# /n/home03/xwei/Desktop/Images/n02096177-cairn
# /n/home03/xwei/Desktop/Images/n02096177-cairn
# /n/home03/xwei/Desktop/Images/n02111889-Samoyed
# /n/home03/xwei/Desktop/Images/n02111889-Samoyed
# /n/home03/xwei/Desktop/Images/n02111889-Samoyed
# /n/home03/xwei/Desktop/Images/n02111889-Samoyed
# /n/home03/xwei/Desktop/Images/n02112018-Pomeranian
# /n/home03/xwei/Desktop/Images/n02112018-Pomeranian
# /n/home03/xwei/Desktop/Images/n02112018-Pomeranian
# /n/home03/xwei/Desktop/Images/n02112018-Pomeranian
# /n/home03/xwei/Desktop/Images/n02097658-silky_terrier
# /n/home03/xwei/Desktop/Images/n02097658-silky_terrier
# /n/home03/xwei/Desktop/Images/n02097658-silky_terrier
# /n/home03/xwei/Desktop/Images/n02097658-silky_terrier
# /n/home03/xwei/Desktop/Images/n02111277-Newfoundland
# /n/home03/xwei/Desktop/Images/n02111277-Newfoundland
# /n/home03/xwei/Desktop/Images/n02111277-Newfoundland
# /n/home03/xwei/Desktop/Images/n02111277-Newfoundland
# /n/home03/xwei/Desktop/Images/n02109047-Great_Dane
# /n/home03/xwei/Desktop/Images/n02109047-Great_Dane
# /n/home03/xwei/Desktop/Images/n02109047-Great_Dane
# /n/home03/xwei/Desktop/Images/n02109047-Great_Dane
# /n/home03/xwei/Desktop/Images/n02102177-Welsh_springer_spaniel
# /n/home03/xwei/Desktop/Images/n02102177-Welsh_springer_spaniel
# /n/home03/xwei/Desktop/Images/n02102177-Welsh_springer_spaniel
# /n/home03/xwei/Desktop/Images/n02102177-Welsh_springer_spaniel
# /n/home03/xwei/Desktop/Images/n02101388-Brittany_spaniel
# /n/home03/xwei/Desktop/Images/n02101388-Brittany_spaniel
# /n/home03/xwei/Desktop/Images/n02101388-Brittany_spaniel
# /n/home03/xwei/Desktop/Images/n02101388-Brittany_spaniel
# /n/home03/xwei/Desktop/Images/n02087394-Rhodesian_ridgeback
# /n/home03/xwei/Desktop/Images/n02087394-Rhodesian_ridgeback
# /n/home03/xwei/Desktop/Images/n02087394-Rhodesian_ridgeback
# /n/home03/xwei/Desktop/Images/n02087394-Rhodesian_ridgeback
# /n/home03/xwei/Desktop/Images/n02093428-American_Staffordshire_terrier
# /n/home03/xwei/Desktop/Images/n02093428-American_Staffordshire_terrier
# /n/home03/xwei/Desktop/Images/n02093428-American_Staffordshire_terrier
# /n/home03/xwei/Desktop/Images/n02093428-American_Staffordshire_terrier
# /n/home03/xwei/Desktop/Images/n02112706-Brabancon_griffon
# /n/home03/xwei/Desktop/Images/n02112706-Brabancon_griffon
# /n/home03/xwei/Desktop/Images/n02112706-Brabancon_griffon
# /n/home03/xwei/Desktop/Images/n02112706-Brabancon_griffon
# /n/home03/xwei/Desktop/Images/n02099267-flat-coated_retriever
# /n/home03/xwei/Desktop/Images/n02099267-flat-coated_retriever
# /n/home03/xwei/Desktop/Images/n02099267-flat-coated_retriever
# /n/home03/xwei/Desktop/Images/n02099267-flat-coated_retriever
# /n/home03/xwei/Desktop/Images/n02106382-Bouvier_des_Flandres
# /n/home03/xwei/Desktop/Images/n02106382-Bouvier_des_Flandres
# /n/home03/xwei/Desktop/Images/n02106382-Bouvier_des_Flandres
# /n/home03/xwei/Desktop/Images/n02106382-Bouvier_des_Flandres
# /n/home03/xwei/Desktop/Images/n02104365-schipperke
# /n/home03/xwei/Desktop/Images/n02104365-schipperke
# /n/home03/xwei/Desktop/Images/n02104365-schipperke
# /n/home03/xwei/Desktop/Images/n02104365-schipperke
# /n/home03/xwei/Desktop/Images/n02105505-komondor
# /n/home03/xwei/Desktop/Images/n02105505-komondor
# /n/home03/xwei/Desktop/Images/n02105505-komondor
# /n/home03/xwei/Desktop/Images/n02105505-komondor
# /n/home03/xwei/Desktop/Images/n02098413-Lhasa
# /n/home03/xwei/Desktop/Images/n02098413-Lhasa
# /n/home03/xwei/Desktop/Images/n02098413-Lhasa
# /n/home03/xwei/Desktop/Images/n02098413-Lhasa
# /n/home03/xwei/Desktop/Images/n02091467-Norwegian_elkhound
# /n/home03/xwei/Desktop/Images/n02091467-Norwegian_elkhound
# /n/home03/xwei/Desktop/Images/n02091467-Norwegian_elkhound
# /n/home03/xwei/Desktop/Images/n02091467-Norwegian_elkhound
# /n/home03/xwei/Desktop/Images/n02105855-Shetland_sheepdog
# /n/home03/xwei/Desktop/Images/n02105855-Shetland_sheepdog
# /n/home03/xwei/Desktop/Images/n02105855-Shetland_sheepdog
# /n/home03/xwei/Desktop/Images/n02105855-Shetland_sheepdog
# /n/home03/xwei/Desktop/Images/n02091244-Ibizan_hound
# /n/home03/xwei/Desktop/Images/n02091244-Ibizan_hound
# /n/home03/xwei/Desktop/Images/n02091244-Ibizan_hound
# /n/home03/xwei/Desktop/Images/n02091244-Ibizan_hound
# /n/home03/xwei/Desktop/Images/n02115913-dhole
# /n/home03/xwei/Desktop/Images/n02115913-dhole
# /n/home03/xwei/Desktop/Images/n02115913-dhole
# /n/home03/xwei/Desktop/Images/n02115913-dhole
# /n/home03/xwei/Desktop/Images/n02107312-miniature_pinscher
# /n/home03/xwei/Desktop/Images/n02107312-miniature_pinscher
# /n/home03/xwei/Desktop/Images/n02107312-miniature_pinscher
# /n/home03/xwei/Desktop/Images/n02107312-miniature_pinscher
# /n/home03/xwei/Desktop/Images/n02092002-Scottish_deerhound
# /n/home03/xwei/Desktop/Images/n02092002-Scottish_deerhound
# /n/home03/xwei/Desktop/Images/n02092002-Scottish_deerhound
# /n/home03/xwei/Desktop/Images/n02092002-Scottish_deerhound
# /n/home03/xwei/Desktop/Images/n02095314-wire-haired_fox_terrier
# /n/home03/xwei/Desktop/Images/n02095314-wire-haired_fox_terrier
# /n/home03/xwei/Desktop/Images/n02095314-wire-haired_fox_terrier
# /n/home03/xwei/Desktop/Images/n02095314-wire-haired_fox_terrier
# /n/home03/xwei/Desktop/Images/n02091831-Saluki
# /n/home03/xwei/Desktop/Images/n02091831-Saluki
# /n/home03/xwei/Desktop/Images/n02091831-Saluki
# /n/home03/xwei/Desktop/Images/n02091831-Saluki
# /n/home03/xwei/Desktop/Images/n02098286-West_Highland_white_terrier
# /n/home03/xwei/Desktop/Images/n02098286-West_Highland_white_terrier
# /n/home03/xwei/Desktop/Images/n02098286-West_Highland_white_terrier
# /n/home03/xwei/Desktop/Images/n02098286-West_Highland_white_terrier
# /n/home03/xwei/Desktop/Images/n02113799-standard_poodle
# /n/home03/xwei/Desktop/Images/n02113799-standard_poodle
# /n/home03/xwei/Desktop/Images/n02113799-standard_poodle
# /n/home03/xwei/Desktop/Images/n02113799-standard_poodle
# /n/home03/xwei/Desktop/Images/n02085620-Chihuahua
# /n/home03/xwei/Desktop/Images/n02085620-Chihuahua
# /n/home03/xwei/Desktop/Images/n02085620-Chihuahua
# /n/home03/xwei/Desktop/Images/n02085620-Chihuahua
# /n/home03/xwei/Desktop/Images/n02097209-standard_schnauzer
# /n/home03/xwei/Desktop/Images/n02097209-standard_schnauzer
# /n/home03/xwei/Desktop/Images/n02097209-standard_schnauzer
# /n/home03/xwei/Desktop/Images/n02097209-standard_schnauzer
# /n/home03/xwei/Desktop/Images/n02088238-basset
# /n/home03/xwei/Desktop/Images/n02088238-basset
# /n/home03/xwei/Desktop/Images/n02088238-basset
# /n/home03/xwei/Desktop/Images/n02088238-basset
# /n/home03/xwei/Desktop/Images/n02113712-miniature_poodle
# /n/home03/xwei/Desktop/Images/n02113712-miniature_poodle
# /n/home03/xwei/Desktop/Images/n02113712-miniature_poodle
# /n/home03/xwei/Desktop/Images/n02113712-miniature_poodle
# /n/home03/xwei/Desktop/Images/n02105412-kelpie
# /n/home03/xwei/Desktop/Images/n02105412-kelpie
# /n/home03/xwei/Desktop/Images/n02105412-kelpie
# /n/home03/xwei/Desktop/Images/n02105412-kelpie
# /n/home03/xwei/Desktop/Images/n02104029-kuvasz
# /n/home03/xwei/Desktop/Images/n02104029-kuvasz
# /n/home03/xwei/Desktop/Images/n02104029-kuvasz
# /n/home03/xwei/Desktop/Images/n02104029-kuvasz
# /n/home03/xwei/Desktop/Images/n02101556-clumber
# /n/home03/xwei/Desktop/Images/n02101556-clumber
# /n/home03/xwei/Desktop/Images/n02101556-clumber
# /n/home03/xwei/Desktop/Images/n02101556-clumber
# /n/home03/xwei/Desktop/Images/n02100583-vizsla
# /n/home03/xwei/Desktop/Images/n02100583-vizsla
# /n/home03/xwei/Desktop/Images/n02100583-vizsla
# /n/home03/xwei/Desktop/Images/n02100583-vizsla
# /n/home03/xwei/Desktop/Images/n02095570-Lakeland_terrier
# /n/home03/xwei/Desktop/Images/n02095570-Lakeland_terrier
# /n/home03/xwei/Desktop/Images/n02095570-Lakeland_terrier
# /n/home03/xwei/Desktop/Images/n02095570-Lakeland_terrier
# /n/home03/xwei/Desktop/Images/n02096051-Airedale
# /n/home03/xwei/Desktop/Images/n02096051-Airedale
# /n/home03/xwei/Desktop/Images/n02096051-Airedale
# /n/home03/xwei/Desktop/Images/n02096051-Airedale
# /n/home03/xwei/Desktop/Images/n02086646-Blenheim_spaniel
# /n/home03/xwei/Desktop/Images/n02086646-Blenheim_spaniel
# /n/home03/xwei/Desktop/Images/n02086646-Blenheim_spaniel
# /n/home03/xwei/Desktop/Images/n02086646-Blenheim_spaniel
# /n/home03/xwei/Desktop/Images/n02113624-toy_poodle
# /n/home03/xwei/Desktop/Images/n02113624-toy_poodle
# /n/home03/xwei/Desktop/Images/n02113624-toy_poodle
# /n/home03/xwei/Desktop/Images/n02113624-toy_poodle
# /n/home03/xwei/Desktop/Images/n02110958-pug
# /n/home03/xwei/Desktop/Images/n02110958-pug
# /n/home03/xwei/Desktop/Images/n02110958-pug
# /n/home03/xwei/Desktop/Images/n02110958-pug
# /n/home03/xwei/Desktop/Images/n02093647-Bedlington_terrier
# /n/home03/xwei/Desktop/Images/n02093647-Bedlington_terrier
# /n/home03/xwei/Desktop/Images/n02093647-Bedlington_terrier
# /n/home03/xwei/Desktop/Images/n02093647-Bedlington_terrier
# /n/home03/xwei/Desktop/Images/n02097298-Scotch_terrier
# /n/home03/xwei/Desktop/Images/n02097298-Scotch_terrier
# /n/home03/xwei/Desktop/Images/n02097298-Scotch_terrier
# /n/home03/xwei/Desktop/Images/n02097298-Scotch_terrier
# /n/home03/xwei/Desktop/Images/n02096294-Australian_terrier
# /n/home03/xwei/Desktop/Images/n02096294-Australian_terrier
# /n/home03/xwei/Desktop/Images/n02096294-Australian_terrier
# /n/home03/xwei/Desktop/Images/n02096294-Australian_terrier
# /n/home03/xwei/Desktop/Images/n02091032-Italian_greyhound
# /n/home03/xwei/Desktop/Images/n02091032-Italian_greyhound
# /n/home03/xwei/Desktop/Images/n02091032-Italian_greyhound
# /n/home03/xwei/Desktop/Images/n02091032-Italian_greyhound
# /n/home03/xwei/Desktop/Images/n02095889-Sealyham_terrier
# /n/home03/xwei/Desktop/Images/n02095889-Sealyham_terrier
# /n/home03/xwei/Desktop/Images/n02095889-Sealyham_terrier
# /n/home03/xwei/Desktop/Images/n02095889-Sealyham_terrier
# /n/home03/xwei/Desktop/Images/n02086910-papillon
# /n/home03/xwei/Desktop/Images/n02086910-papillon
# /n/home03/xwei/Desktop/Images/n02086910-papillon
# /n/home03/xwei/Desktop/Images/n02086910-papillon
# /n/home03/xwei/Desktop/Images/n02088094-Afghan_hound
# /n/home03/xwei/Desktop/Images/n02088094-Afghan_hound
# /n/home03/xwei/Desktop/Images/n02088094-Afghan_hound
# /n/home03/xwei/Desktop/Images/n02088094-Afghan_hound
# /n/home03/xwei/Desktop/Images/n02088364-beagle
# /n/home03/xwei/Desktop/Images/n02088364-beagle
# /n/home03/xwei/Desktop/Images/n02088364-beagle
# /n/home03/xwei/Desktop/Images/n02088364-beagle
# /n/home03/xwei/Desktop/Images/n02108089-boxer
# /n/home03/xwei/Desktop/Images/n02108089-boxer
# /n/home03/xwei/Desktop/Images/n02108089-boxer
# /n/home03/xwei/Desktop/Images/n02108089-boxer
# /n/home03/xwei/Desktop/Images/n02097047-miniature_schnauzer
# /n/home03/xwei/Desktop/Images/n02097047-miniature_schnauzer
# /n/home03/xwei/Desktop/Images/n02097047-miniature_schnauzer
# /n/home03/xwei/Desktop/Images/n02097047-miniature_schnauzer
# /n/home03/xwei/Desktop/Images/n02112137-chow
# /n/home03/xwei/Desktop/Images/n02112137-chow
# /n/home03/xwei/Desktop/Images/n02112137-chow
# /n/home03/xwei/Desktop/Images/n02112137-chow
# /n/home03/xwei/Desktop/Images/n02113186-Cardigan
# /n/home03/xwei/Desktop/Images/n02113186-Cardigan
# /n/home03/xwei/Desktop/Images/n02113186-Cardigan
# /n/home03/xwei/Desktop/Images/n02113186-Cardigan
# /n/home03/xwei/Desktop/Images/n02115641-dingo
# /n/home03/xwei/Desktop/Images/n02115641-dingo
# /n/home03/xwei/Desktop/Images/n02115641-dingo
# /n/home03/xwei/Desktop/Images/n02115641-dingo
# /n/home03/xwei/Desktop/Images/n02110627-affenpinscher
# /n/home03/xwei/Desktop/Images/n02110627-affenpinscher
# /n/home03/xwei/Desktop/Images/n02110627-affenpinscher
# /n/home03/xwei/Desktop/Images/n02110627-affenpinscher
# /n/home03/xwei/Desktop/Images/n02110806-basenji
# /n/home03/xwei/Desktop/Images/n02110806-basenji
# /n/home03/xwei/Desktop/Images/n02110806-basenji
# /n/home03/xwei/Desktop/Images/n02110806-basenji
# /n/home03/xwei/Desktop/Images/n02093754-Border_terrier
# /n/home03/xwei/Desktop/Images/n02093754-Border_terrier
# /n/home03/xwei/Desktop/Images/n02093754-Border_terrier
# /n/home03/xwei/Desktop/Images/n02093754-Border_terrier
# /n/home03/xwei/Desktop/Images/n02093859-Kerry_blue_terrier
# /n/home03/xwei/Desktop/Images/n02093859-Kerry_blue_terrier
# /n/home03/xwei/Desktop/Images/n02093859-Kerry_blue_terrier
# /n/home03/xwei/Desktop/Images/n02093859-Kerry_blue_terrier
# /n/home03/xwei/Desktop/Images/n02105251-briard
# /n/home03/xwei/Desktop/Images/n02105251-briard
# /n/home03/xwei/Desktop/Images/n02105251-briard
# /n/home03/xwei/Desktop/Images/n02105251-briard
# /n/home03/xwei/Desktop/Images/n02089973-English_foxhound
# /n/home03/xwei/Desktop/Images/n02089973-English_foxhound
# /n/home03/xwei/Desktop/Images/n02089973-English_foxhound
# /n/home03/xwei/Desktop/Images/n02089973-English_foxhound
# /n/home03/xwei/Desktop/Images/n02111129-Leonberg
# /n/home03/xwei/Desktop/Images/n02111129-Leonberg
# /n/home03/xwei/Desktop/Images/n02111129-Leonberg
# /n/home03/xwei/Desktop/Images/n02111129-Leonberg
# /n/home03/xwei/Desktop/Images/n02091635-otterhound
# /n/home03/xwei/Desktop/Images/n02091635-otterhound
# /n/home03/xwei/Desktop/Images/n02091635-otterhound
# /n/home03/xwei/Desktop/Images/n02091635-otterhound
# /n/home03/xwei/Desktop/Images/n02102040-English_springer
# /n/home03/xwei/Desktop/Images/n02102040-English_springer
# /n/home03/xwei/Desktop/Images/n02102040-English_springer
# /n/home03/xwei/Desktop/Images/n02102040-English_springer
# /n/home03/xwei/Desktop/Images/n02093256-Staffordshire_bullterrier
# /n/home03/xwei/Desktop/Images/n02093256-Staffordshire_bullterrier
# /n/home03/xwei/Desktop/Images/n02093256-Staffordshire_bullterrier
# /n/home03/xwei/Desktop/Images/n02093256-Staffordshire_bullterrier
# /n/home03/xwei/Desktop/Images/n02089867-Walker_hound
# /n/home03/xwei/Desktop/Images/n02089867-Walker_hound
# /n/home03/xwei/Desktop/Images/n02089867-Walker_hound
# /n/home03/xwei/Desktop/Images/n02089867-Walker_hound
# /n/home03/xwei/Desktop/Images/n02096585-Boston_bull
# /n/home03/xwei/Desktop/Images/n02096585-Boston_bull
# /n/home03/xwei/Desktop/Images/n02096585-Boston_bull
# /n/home03/xwei/Desktop/Images/n02096585-Boston_bull
# /n/home03/xwei/Desktop/Images/n02100735-English_setter
# /n/home03/xwei/Desktop/Images/n02100735-English_setter
# /n/home03/xwei/Desktop/Images/n02100735-English_setter
# /n/home03/xwei/Desktop/Images/n02100735-English_setter
# /n/home03/xwei/Desktop/Images/n02102480-Sussex_spaniel
# /n/home03/xwei/Desktop/Images/n02102480-Sussex_spaniel
# /n/home03/xwei/Desktop/Images/n02102480-Sussex_spaniel
# /n/home03/xwei/Desktop/Images/n02102480-Sussex_spaniel
# /n/home03/xwei/Desktop/Images/n02116738-African_hunting_dog
# /n/home03/xwei/Desktop/Images/n02116738-African_hunting_dog
# /n/home03/xwei/Desktop/Images/n02116738-African_hunting_dog
# /n/home03/xwei/Desktop/Images/n02116738-African_hunting_dog
# /n/home03/xwei/Desktop/Images/n02092339-Weimaraner
# /n/home03/xwei/Desktop/Images/n02092339-Weimaraner
# /n/home03/xwei/Desktop/Images/n02092339-Weimaraner
# /n/home03/xwei/Desktop/Images/n02092339-Weimaraner
# /n/home03/xwei/Desktop/Images/n02107683-Bernese_mountain_dog
# /n/home03/xwei/Desktop/Images/n02107683-Bernese_mountain_dog
# /n/home03/xwei/Desktop/Images/n02107683-Bernese_mountain_dog
# /n/home03/xwei/Desktop/Images/n02107683-Bernese_mountain_dog
# /n/home03/xwei/Desktop/Images/n02099849-Chesapeake_Bay_retriever
# /n/home03/xwei/Desktop/Images/n02099849-Chesapeake_Bay_retriever
# /n/home03/xwei/Desktop/Images/n02099849-Chesapeake_Bay_retriever
# /n/home03/xwei/Desktop/Images/n02099849-Chesapeake_Bay_retriever
# /n/home03/xwei/Desktop/Images/n02090721-Irish_wolfhound
# /n/home03/xwei/Desktop/Images/n02090721-Irish_wolfhound
# /n/home03/xwei/Desktop/Images/n02090721-Irish_wolfhound
# /n/home03/xwei/Desktop/Images/n02090721-Irish_wolfhound
# /n/home03/xwei/Desktop/Images/n02108000-EntleBucher
# /n/home03/xwei/Desktop/Images/n02108000-EntleBucher
# /n/home03/xwei/Desktop/Images/n02108000-EntleBucher
# /n/home03/xwei/Desktop/Images/n02108000-EntleBucher
# /n/home03/xwei/Desktop/Images/n02108915-French_bulldog
# /n/home03/xwei/Desktop/Images/n02108915-French_bulldog
# /n/home03/xwei/Desktop/Images/n02108915-French_bulldog
# /n/home03/xwei/Desktop/Images/n02108915-French_bulldog
# /n/home03/xwei/Desktop/Images/n02087046-toy_terrier
# /n/home03/xwei/Desktop/Images/n02087046-toy_terrier
# /n/home03/xwei/Desktop/Images/n02087046-toy_terrier
# /n/home03/xwei/Desktop/Images/n02087046-toy_terrier
# /n/home03/xwei/Desktop/Images/n02105056-groenendael
# /n/home03/xwei/Desktop/Images/n02105056-groenendael
# /n/home03/xwei/Desktop/Images/n02105056-groenendael
# /n/home03/xwei/Desktop/Images/n02105056-groenendael
# /n/home03/xwei/Desktop/Images/n02093991-Irish_terrier
# /n/home03/xwei/Desktop/Images/n02093991-Irish_terrier
# /n/home03/xwei/Desktop/Images/n02093991-Irish_terrier
# /n/home03/xwei/Desktop/Images/n02093991-Irish_terrier
# /n/home03/xwei/Desktop/Images/n02113023-Pembroke
# /n/home03/xwei/Desktop/Images/n02113023-Pembroke
# /n/home03/xwei/Desktop/Images/n02113023-Pembroke
# /n/home03/xwei/Desktop/Images/n02113023-Pembroke
# /n/home03/xwei/Desktop/Images/n02106030-collie
# /n/home03/xwei/Desktop/Images/n02106030-collie
# /n/home03/xwei/Desktop/Images/n02106030-collie
# /n/home03/xwei/Desktop/Images/n02106030-collie
# /n/home03/xwei/Desktop/Images/n02098105-soft-coated_wheaten_terrier
# /n/home03/xwei/Desktop/Images/n02098105-soft-coated_wheaten_terrier
# /n/home03/xwei/Desktop/Images/n02098105-soft-coated_wheaten_terrier
# /n/home03/xwei/Desktop/Images/n02098105-soft-coated_wheaten_terrier
# /n/home03/xwei/Desktop/Images/n02113978-Mexican_hairless
# /n/home03/xwei/Desktop/Images/n02113978-Mexican_hairless
# /n/home03/xwei/Desktop/Images/n02113978-Mexican_hairless
# /n/home03/xwei/Desktop/Images/n02113978-Mexican_hairless
# /n/home03/xwei/Desktop/Images/n02085936-Maltese_dog
# /n/home03/xwei/Desktop/Images/n02085936-Maltese_dog
# /n/home03/xwei/Desktop/Images/n02085936-Maltese_dog
# /n/home03/xwei/Desktop/Images/n02085936-Maltese_dog
# /n/home03/xwei/Desktop/Images/n02108422-bull_mastiff
# /n/home03/xwei/Desktop/Images/n02108422-bull_mastiff
# /n/home03/xwei/Desktop/Images/n02108422-bull_mastiff
# /n/home03/xwei/Desktop/Images/n02108422-bull_mastiff
# /n/home03/xwei/Desktop/Images/n02101006-Gordon_setter
# /n/home03/xwei/Desktop/Images/n02101006-Gordon_setter
# /n/home03/xwei/Desktop/Images/n02101006-Gordon_setter
# /n/home03/xwei/Desktop/Images/n02101006-Gordon_setter
# /n/home03/xwei/Desktop/Images/n02110185-Siberian_husky
# /n/home03/xwei/Desktop/Images/n02110185-Siberian_husky
# /n/home03/xwei/Desktop/Images/n02110185-Siberian_husky
# /n/home03/xwei/Desktop/Images/n02110185-Siberian_husky

# %%
meta
# Out:
# [array([[[ 70,  38,  25],
#          [ 74,  42,  29],
#          [ 69,  37,  24],
#          ...,
#          [  0,   0,   0],
#          [  0,   0,   0],
#          [  0,   0,   0]],
#
#         [[ 72,  42,  28],
#          [ 73,  41,  28],
#          [ 67,  34,  25],
#          ...,
#          [  0,   0,   0],
#          [  0,   0,   0],
#          [  0,   0,   0]],
#
#         [[ 68,  38,  24],
#          [ 73,  41,  28],
#          [ 65,  32,  23],
#          ...,
#          [  0,   0,   0],
#          [  0,   0,   0],
#          [  0,   0,   0]],
#
#         ...,
#         [[ 60,  61,  52],
#          [ 68,  70,  59],
#          [ 66,  68,  57],
#          ...,
#          [  0,   0,   0],
#          [  0,   0,   0],
#          [  0,   0,   0]],
#
#         [[ 83,  85,  80],
#          [ 86,  89,  88],
#          [ 87,  91,  89],
#          ...,
#          [  0,   0,   0],
#          [  0,   0,   0],
#          [  0,   0,   0]],
#
#         [[134, 138, 143],
#          [135, 140, 145],
#          [137, 142, 147],
#          ...,
#          [  0,   0,   0],
#          [  0,   0,   0],
#          [  0,   0,   0]]]), 'siberian husky', 'Working Group']

# %%
X_train = np.array([m[0] for m in data_train])
y_train = [m[2] for m in data_train]
group2num = {'Working Group':0,'Sporting Group':1,'Hound Group':2,'Herding Group':3,
             'Toy Group':4,'Terrier Group':5,'Non-Sporting Group':6,'Foundation Stock Service':7,'Hybrid':7,'NAN':7}
y_train = np.array(to_categorical([group2num[y] for y in y_train],8))

# %%
# Building a simple CNN
cnn_md1 = Sequential([
    Conv2D(32,kernel_size=(7,7),padding='same',activation='relu',use_bias=True,kernel_initializer='normal',input_shape=(64,64,3,)),
    Conv2D(32,kernel_size=(7,7),padding='same',activation='relu',use_bias=True,kernel_initializer='normal'),
    MaxPooling2D(strides=(2,2)),
    Conv2D(64,kernel_size=(5,5),padding='same',activation='relu',use_bias=True,kernel_initializer='normal'),
    Conv2D(64,kernel_size=(5,5),padding='same',activation='relu',use_bias=True,kernel_initializer='normal'),
    MaxPooling2D(strides=(2,2)),
    Conv2D(128,kernel_size=(3,3),padding='same',activation='relu',use_bias=True,kernel_initializer='normal'),
    Conv2D(128,kernel_size=(3,3),padding='same',activation='relu',use_bias=True,kernel_initializer='normal'),
    MaxPooling2D(strides=(2,2)),
    Conv2D(256,kernel_size=(3,3),padding='same',activation='relu',use_bias=True,kernel_initializer='normal'),
    Conv2D(256,kernel_size=(3,3),padding='same',activation='relu',use_bias=True,kernel_initializer='normal'),
    MaxPooling2D(strides=(2,2)),
    Conv2D(512,kernel_size=(3,3),padding='same',activation='relu',use_bias=True,kernel_initializer='normal'),
    Conv2D(512,kernel_size=(3,3),padding='same',activation='relu',use_bias=True,kernel_initializer='normal'),
    MaxPooling2D(strides=(2,2)),
    Flatten(),
    Dense(512,activation='relu'),
    Dense(8,activation='softmax')
])
cnn_md1.compile('adam','categorical_crossentropy',['acc'])

# %%
history1 = cnn_md1.fit(X_train,y_train,batch_size=32,epochs=15,validation_split=0.2)
# Out:
# Train on 288 samples, validate on 72 samples
# Epoch 1/15
# 288/288 [==============================] - 43s 149ms/step - loss: 14.1552 - acc: 0.1215 - val_loss: 14.1033 - val_acc: 0.1250
# Epoch 2/15
# 288/288 [==============================] - 42s 146ms/step - loss: 13.4317 - acc: 0.1667 - val_loss: 14.1033 - val_acc: 0.1250
# Epoch 3/15
# 288/288 [==============================] - 42s 146ms/step - loss: 13.4317 - acc: 0.1667 - val_loss: 14.1033 - val_acc: 0.1250
# Epoch 4/15
# 288/288 [==============================] - 42s 146ms/step - loss: 13.4317 - acc: 0.1667 - val_loss: 14.1033 - val_acc: 0.1250
# Epoch 5/15
# 288/288 [==============================] - 42s 146ms/step - loss: 13.4317 - acc: 0.1667 - val_loss: 14.1033 - val_acc: 0.1250
# Epoch 6/15
# 288/288 [==============================] - 42s 146ms/step - loss: 13.4317 - acc: 0.1667 - val_loss: 14.1033 - val_acc: 0.1250
# Epoch 7/15
# 288/288 [==============================] - 42s 147ms/step - loss: 13.4317 - acc: 0.1667 - val_loss: 14.1033 - val_acc: 0.1250
# Epoch 8/15
# 288/288 [==============================] - 42s 146ms/step - loss: 13.4317 - acc: 0.1667 - val_loss: 14.1033 - val_acc: 0.1250
# Epoch 9/15
# 288/288 [==============================] - 42s 146ms/step - loss: 13.4317 - acc: 0.1667 - val_loss: 14.1033 - val_acc: 0.1250
# Epoch 10/15
# 288/288 [==============================] - 42s 146ms/step - loss: 13.4317 - acc: 0.1667 - val_loss: 14.1033 - val_acc: 0.1250
# Epoch 11/15
# 288/288 [==============================] - 42s 146ms/step - loss: 13.4317 - acc: 0.1667 - val_loss: 14.1033 - val_acc: 0.1250
# Epoch 12/15
# 288/288 [==============================] - 42s 147ms/step - loss: 13.4317 - acc: 0.1667 - val_loss: 14.1033 - val_acc: 0.1250
# Epoch 13/15
# 288/288 [==============================] - 42s 147ms/step - loss: 13.4317 - acc: 0.1667 - val_loss: 14.1033 - val_acc: 0.1250
# Epoch 14/15
# 288/288 [==============================] - 42s 147ms/step - loss: 13.4317 - acc: 0.1667 - val_loss: 14.1033 - val_acc: 0.1250
# Epoch 15/15
# 288/288 [==============================] - 42s 147ms/step - loss: 13.4317 - acc: 0.1667 - val_loss: 14.1033 - val_acc: 0.1250

# %%
# ann_md2 = Sequential([
#     Dense(128,input_shape=(250,250,3,),activation='relu'),
#     Flatten(),
#     Dense(128,activation='relu'),
#     Dense(8,activation='softmax')
# ])
# ann_md2.compile('sgd','categorical_crossentropy',['acc'])
# history2 = ann_md2.fit(X_train,y_train,batch_size=1,epochs=15,validation_split=0.2)

# %%
X_train_scaled = X_train.copy()
for i in range(3):
    X_train_scaled[:,:,:,i] = (X_train[:,:,:,i]-np.mean(X_train[:,:,:,i]))/np.std(X_train[:,:,:,i])

# %%
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)
datagen.fit(X_train)
cnn_md1.fit_generator(datagen.flow(X_train_scaled, y_train, batch_size=32),
                    steps_per_epoch=len(X_train_scaled) / 32, epochs=15)
# Out:
# Epoch 1/15
# 12/11 [================================] - 51s 4s/step - loss: 13.6033 - acc: 0.1558
# Epoch 2/15
# 12/11 [================================] - 49s 4s/step - loss: 13.3646 - acc: 0.1708
# Epoch 3/15
# 12/11 [================================] - 50s 4s/step - loss: 13.5971 - acc: 0.1564
# Epoch 4/15
# 12/11 [================================] - 50s 4s/step - loss: 13.7133 - acc: 0.1492
# Epoch 5/15
# 12/11 [================================] - 50s 4s/step - loss: 13.7133 - acc: 0.1492
# Epoch 6/15
# 12/11 [================================] - 50s 4s/step - loss: 13.5971 - acc: 0.1564
# Epoch 7/15
# 12/11 [================================] - 50s 4s/step - loss: 13.5971 - acc: 0.1564
# Epoch 8/15
# 12/11 [================================] - 50s 4s/step - loss: 13.5971 - acc: 0.1564
# Epoch 9/15
# 12/11 [================================] - 50s 4s/step - loss: 13.5971 - acc: 0.1564
# Epoch 10/15
# 12/11 [================================] - 50s 4s/step - loss: 13.5971 - acc: 0.1564
# Epoch 11/15
# 12/11 [================================] - 50s 4s/step - loss: 13.2484 - acc: 0.1780
# Epoch 12/15
# 12/11 [================================] - 50s 4s/step - loss: 13.5971 - acc: 0.1564
# Epoch 13/15
# 12/11 [================================] - 50s 4s/step - loss: 13.4808 - acc: 0.1636
# Epoch 14/15
# 12/11 [================================] - 50s 4s/step - loss: 13.5971 - acc: 0.1564
# Epoch 15/15
# 12/11 [================================] - 50s 4s/step - loss: 13.4808 - acc: 0.1636

# %%
# key is breed name and value is list containing the 10 images this is the same thing above, 
#we accidentally had 2 group members do the same thing which was making a dictionary of values of breed to breed class
file_type=pd.read_csv('file',header=None,names=['filename','type'])

file_type['annotations']=['Annotation/'+i.replace('.jpg','') for i in file_type.filename.values]
file_type['breed']=[i.split('/')[0].split('-')[1] for i in file_type.filename.values]
a_ = np.zeros((file_type.filename.values.shape[0],4))
a_.shape

for index,row in file_type.iterrows():
    with open(row['annotations'],'r') as fp:
                soup = BeautifulSoup(fp.read(),'html.parser')
                xmin = int(soup.select_one('xmin').text)
                xmax = int(soup.select_one('xmax').text)
                ymin = int(soup.select_one('ymin').text)
                ymax = int(soup.select_one('ymax').text)
                img = [ymin,ymax,xmin,xmax]
                a_[index,:]=img

file_type=pd.concat([file_type,pd.DataFrame(a_,columns=['ymin','ymax','xmin','xmax'])],axis=1)

# %%
breeds_10=list()
class_dictionary={}
for i in range(1,121):
    breed=dict()
    breed['breed']=file_type['breed'].loc[file_type.type==i].values[0]
    breed['type_num']=i
    breed['breed_class']=groups[breed['breed'].lower().replace('_',' ')]
    class_dictionary[file_type['breed'].loc[file_type.type==i].values[0]]=breed['breed_class']
    
    for index, row in file_type.loc[file_type.type==i].iterrows():
        if index>9: 
            break
        else: continue
    breeds_10.append(breed)
file_type['breed_class']=[groups[i.lower().replace('_',' ')] for i in file_type.breed.values]
yy=file_type['breed'].value_counts()
file_type.head()
# Out:
#                                   filename  type  \
# 0  n02085620-Chihuahua/n02085620_10074.jpg     1
# 1  n02085620-Chihuahua/n02085620_10131.jpg     1
# 2  n02085620-Chihuahua/n02085620_10621.jpg     1
# 3   n02085620-Chihuahua/n02085620_1073.jpg     1
# 4  n02085620-Chihuahua/n02085620_10976.jpg     1
#
#                                       annotations      breed   ymin   ymax  \
# 0  Annotation/n02085620-Chihuahua/n02085620_10074  Chihuahua   10.0  498.0
# 1  Annotation/n02085620-Chihuahua/n02085620_10131  Chihuahua    9.0  493.0
# 2  Annotation/n02085620-Chihuahua/n02085620_10621  Chihuahua   43.0  250.0
# 3   Annotation/n02085620-Chihuahua/n02085620_1073  Chihuahua   27.0  498.0
# 4  Annotation/n02085620-Chihuahua/n02085620_10976  Chihuahua  104.0  452.0
#
#     xmin   xmax breed_class
# 0   25.0  276.0   Toy Group
# 1   49.0  393.0   Toy Group
# 2  142.0  335.0   Toy Group
# 3    0.0  312.0   Toy Group
# 4   90.0  242.0   Toy Group

# %%
fig, ax = plt.subplots()
fig.set_size_inches(25, 30)
sns.set()
ax = sns.barplot(y = yy.index, x = yy, data = file_type,orient='h')
#ax.set_xticklabels(ax.get_yticklabels(), rotation = 90, fontsize = 8)
ax.set_xlabel('Dog Breed',fontsize=20,fontweight='bold')
ax.set_ylabel('Count',fontsize=20,fontweight='bold')
ax.set_title('Distribution of Dog breeds',fontsize=20,fontweight='bold')
plt.tight_layout()
plt.savefig('distribution_breeds.png')
yy=file_type['breed_class'].value_counts()

fig, ax = plt.subplots()
fig.set_size_inches(10,10)
sns.set()
ax = sns.barplot(y = yy.index, x = yy, data = file_type,orient='h')
#ax.set_xticklabels(ax.get_yticklabels(), rotation = 90, fontsize = 8)
ax.set(ylabel='Dog Breed', xlabel='Count')
ax.set_title('Distribution of Dog Breed Classes')
plt.savefig('distribution_class.png',fontsize=20)

# %%
file_type.head()
# Out:
#                                   filename  type      breed breed_class
# 0  n02085620-Chihuahua/n02085620_10074.jpg     1  Chihuahua   Toy Group
# 1  n02085620-Chihuahua/n02085620_10131.jpg     1  Chihuahua   Toy Group
# 2  n02085620-Chihuahua/n02085620_10621.jpg     1  Chihuahua   Toy Group
# 3   n02085620-Chihuahua/n02085620_1073.jpg     1  Chihuahua   Toy Group
# 4  n02085620-Chihuahua/n02085620_10976.jpg     1  Chihuahua   Toy Group

# %%
for i in file_type.breed_class.unique():
# Out:
# array(['Toy Group', 'Hound Group', 'Sporting Group', 'Terrier Group',
#        'Non-Sporting Group', 'Working Group', 'Herding Group',
#        'Foundation Stock Service', 'Hybrid', 'NAN'], dtype=object)

# %%
resnet_md = ResNet50(input_shape=(64,64,3,),classes=8,include_top=True,weights=None)
resnet_md.compile('adam','categorical_crossentropy',['acc'])
history3 = resnet_md.fit(X_train_scaled,y_train,batch_size=24,epochs=15,validation_split=0.2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-fee1f54bbf6a> in <module>()
# ----> 1 resnet_md = ResNet50(input_shape=(64,64,3,),classes=8,include_top=True,weights=None)
#       2 resnet_md.compile('adam','categorical_crossentropy',['acc'])
#       3 history3 = resnet_md.fit(X_train_scaled,y_train,batch_size=24,epochs=15,validation_split=0.2)
#
# /n/home00/ashaw/.conda/envs/ody/lib/python3.6/site-packages/keras_applications/resnet50.py in ResNet50(include_top, weights, input_tensor, input_shape, pooling, classes)
#     207                                       data_format=backend.image_data_format(),
#     208                                       require_flatten=include_top,
# --> 209                                       weights=weights)
#     210
#     211     if input_tensor is None:
#
# /n/home00/ashaw/.conda/envs/ody/lib/python3.6/site-packages/keras_applications/imagenet_utils.py in _obtain_input_shape(input_shape, default_size, min_size, data_format, require_flatten, weights)
#     314                                      str(min_size) + 'x' + str(min_size) +
#     315                                      '; got `input_shape=' +
# --> 316                                      str(input_shape) + '`')
#     317     else:
#     318         if require_flatten:
#
# ValueError: Input size must be at least 197x197; got `input_shape=(64, 64, 3)`
